# %% [markdown]
# # 1️⃣ MRO Internal Working (C3 Linearization)
# 1. ```C3 Linearization``` is the algorithm Python uses to compute the Method Resolution Order (MRO) in multiple and hybrid inheritance.
# 2. It guarantees:
#     - Consistent order
#     - No duplication
#     - Child before parent
#     - Left-to-right priority
#     - Monotonicity (order of parents preserved)
# 3. How C3 Works (Formula)
#     - ```python The MRO of a class is:
#       MRO(Class) = [Class] + merge(MRO(Parent1), MRO(Parent2), ..., [Parent1, Parent2])

# %% [markdown]
# ### **Example**

# %% [markdown]
# ```python
# class C(A, B)
# Python calculates: MRO(C) = [C] + merge(MRO(A), MRO(B), [A, B])
#
# Step-by-Step C3 Merge:
#
# class A: pass
#
# class B(A): pass
#
# class C(A): pass
#
# class D(B, C): pass
#
# Step 1️⃣: Write MRO of Parents
#
# MRO(A) = [A, object]
# MRO(B) = [B, A, object]
# MRO(C) = [C, A, object]
#
# Now calculate:
#
# MRO(D) = [D] + merge(MRO(B), MRO(C), [B, C])
# MRO(D) = [D] + merge([B, A, object], [C, A, object],[B, C])
#
# Step 2️⃣: Apply Merge Rule
#
#
# 📌 Head: The first element of a list.
#
# 📌 Tail: All remaining elements after the head.
#
# Example L = [A, B, C]
# - Head = A
# - Tail = [B, C]
#
# Merge Rule:
# 1. Take first element of first list.
# 2. Check if it appears in tail of any other list.
# 3. If NOT → select it.
# 4. Remove it from all lists.
# 5. Repeat.

# %% [markdown]
# **Round 1**
# ```python
# Candidate = B
#
# Check tails:
#
# Tail of [C, A, object] → [A, object] → no B
#
# Tail of [B, C] → [C] → no B
#
# Result so far:
#
# [D, B]
#
# Remove B from all lists.
#
# Remaining:
# [A, object], [C, A, object], [C]

# %% [markdown]
# **Round 2**
# ```python
# Candidate = A
#
# Check tails:
#
# Tail of [C, A, object] → [A, object] → A exists ❌
#
# So skip A.
#
# Next candidate = C
#
# Check tails:
#
# Tail of [A, object] → [object] → no C
#
# Tail of [C] → [] → no C
#
# Result: [D, B, C]
#
# Remaining: [A, object], [A, object]

# %% [markdown]
# **Round 3**
# ```python
#
# Candidate = A
#
# Check tails:
#
# Tail of second list → [object] → no A
#
# Result: [D, B, C, A]
#
# Remove A.
#
# Remaining: [object], [object]

# %% [markdown]
# **Final**
# ```python
# Add object: MRO(D) = [D, B, C, A, object]

# %% [markdown]
# # 2️⃣ TypeError MRO Conflict Example

# %% [markdown]
# #### ❌ Problematic Structure

# %%
class X: pass
class Y: pass

class A(X, Y): pass
class B(Y, X): pass

class C(A, B): pass

# %% [markdown]
# **What happens?**
# - Python throws:
# - TypeError: Cannot create a consistent method resolution order
# - Why?
#     - A says → X before Y
#     - B says → Y before X
#     - Now C inherits:
# - Python must satisfy BOTH:
#     - X before Y  (from A)
#     - Y before X  (from B)
#     - ```Impossible``` , C3 cannot resolve this contradiction.
