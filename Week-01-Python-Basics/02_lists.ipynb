# %% [markdown]
# # List :
# ### If we want to represent a group of values as single entity.
#
# 1. Insetion Order is perserved
# 2. Heterogeneous Objects are allowed
# 3. Duplicates are allowed
# 4. Growable in nature
# 5. Values should be enclosed within square brackets

# %%
# empty list

l = [] 
print(type(l))
# Out:
# <class 'list'>

# %% [markdown]
# **type():** is a built-in function used to find the data type of a variable or value.

# %%
l = [10,"ajay",20,30,10]
l1 = l
print(l is l1)
print(l)
# Out:
# True
# [10, 'ajay', 20, 30, 10]

# %%
l = []
l.append(10)
l.append(20)
l.append(30)
l.append(40)
print(l)
# Out:
# [10, 20, 30, 40]

# %%
print(l)
l.remove(30)
print(l)
# Out:
# [10, 20, 30, 40]
# [10, 20, 40]
