# %% [markdown]
# # Python Tuples — Complete Guide (Beginner to Confident)
# 1️⃣ **What is a Tuple?** A tuple is an ordered, immutable collection of elements.
# 1. Ordered → elements have positions (index)
# 2. Immutable → elements cannot be changed after creation
# 3. Collection → can store multiple values
#
# 2️⃣ **Why Tuples Exist?**
# 1. Tuples exist to represent fixed, safe data
# 2. They prevent accidental modification
# 3. Real-Life Analogy
#     - Date of Birth → cannot change
#     - GPS Coordinates → fixed
#     - RGB color values → fixed once defined
#
# **NOTE:** Tuple is Read only version of List.

# %% [markdown]
# ### Creating a Tuple

# %% [markdown]
# **Using Parentheses**

# %%
t = (10, 20, 30)
t
# Out:
# (10, 20, 30)

# %% [markdown]
# **Tuple Without Parentheses (Tuple Packing)**

# %%
t = 10, 20, 30, 40
t
# Out:
# (10, 20, 30, 40)

# %% [markdown]
# **Single-Element Tuple**

# %%
t = (10) # ❌ This is NOT a tuple.
type(t)
# Out:
# int

# %%
t = (10,) # Comma is mandatory for single-element tuple.
type(t)
# Out:
# tuple

# %% [markdown]
# 4️⃣ **Tuple Properties**
# | Property          | Tuple |
# | ----------------- | ----- |
# | Ordered           | ✅     |
# | Allows duplicates | ✅     |
# | Mutable           | ❌     |
# | Indexed           | ✅     |
# | Faster than list  | ✅     |

# %% [markdown]
# 5️⃣ **Accessing Tuple Elements (Indexing)**
# - Same indexing rules as lists.

# %%
t = (10, 20, 30, 40)
t[0]
# Out:
# 10

# %% [markdown]
# 6️⃣ **Slicing Tuples**
# - Returns a new tuple
# - Original tuple unchanged

# %%
t = (10, 20, 30, 40, 50)
t[1:4]
# Out:
# (20, 30, 40)

# %% [markdown]
# 7️⃣ **Immutability**

# %%
t = (10, 20, 30)
t[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[137], line 2
#       1 t = (10, 20, 30)
# ----> 2 t[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 8️⃣ **Tuple vs List**
#
# | Feature  | List          | Tuple      |
# | -------- | ------------- | ---------- |
# | Mutable  | ✅             | ❌          |
# | Syntax   | `[]`          | `()`       |
# | Speed    | Slower        | Faster     |
# | Safety   | Less          | More       |
# | Use case | Changing data | Fixed data |

# %% [markdown]
# 9️⃣ **Looping Through a Tuple**
# - Same as list iteration
# - But no modification allowed

# %%
t = (10, 20, 30)

for x in t:
    print(x)
# Out:
# 10
# 20
# 30

# %% [markdown]
# 🔟 **Tuple Operations**
# 1.  Concatenation (+)
# 2.  Repetition (*)
# 3.  Membership (in / not in)

# %%
t1 = (1, 2)
t2 = (3, 4)
t1 + t2, t1*2 , 10 in (10, 20, 30)
# Out:
# ((1, 2, 3, 4), (1, 2, 1, 2), True)

# %% [markdown]
# 1️⃣1️⃣ **Built-in Functions with Tuples**
# - Works same as lists
# - Data must be numeric

# %%
t = (10, 20, 30)

print(len(t))
print(min(t))
print(max(t))
print(sum(t))
# Out:
# 3
# 10
# 30
# 60

# %% [markdown]
# 1️⃣2️⃣ **Tuple Methods**
# - Tuples are immutable, so very few methods exist.
# - No append, remove, sort, etc.

# %% [markdown]
# **count()**

# %%
t = (10,20,30,40,10,50,10)
t.count(10)
# Out:
# 3

# %% [markdown]
# **index()**

# %%
t.index(50)
# Out:
# 5

# %% [markdown]
# 1️⃣3️⃣ **Tuple Packing & Unpacking**

# %%
record = ("Ajay", 25, "India") # Packing 
name, age, country = record # unpacking
name,age,country
# Out:
# ('Ajay', 25, 'India')
